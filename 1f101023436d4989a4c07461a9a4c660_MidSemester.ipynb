# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random, time
class Environment(object):
    def __init__(self):
        self.Location = ["A", "B", "C", "D", "E", "F", "G", "H"]
        self.locationCondition = {"A" : "0", "B" : "0", "C" : "0", "D" : "0", "E" : "0", "F" : "0", "G" : "0", "H" : "0"}
        self.roverAgentLocation = random.choice(self.Location)
        
        self.locationCondition["A"] = random.randint(0,1)
        self.locationCondition["B"] = random.randint(0,1)
        self.locationCondition["C"] = random.randint(0,1)
        self.locationCondition["D"] = random.randint(0,1)
        self.locationCondition["E"] = random.randint(0,1)
        self.locationCondition["F"] = random.randint(0,1)
        self.locationCondition["G"] = random.randint(0,1)
        self.locationCondition["H"] = random.randint(0,1)
        
class roverAgent(Environment):
    def __init__(self, Environment):
        print("---- Exploration Venture 0 -----")
        print(Environment.locationCondition)
        print("Rover is in location ", Environment.roverAgentLocation)
        
        count = 0
        while count < 8:
            if Environment.locationCondition[Environment.roverAgentLocation] == 1:
                Environment.locationCondition[Environment.roverAgentLocation] = 0
                print(Environment.roverAgentLocation, " has been sampled")
            else:
                Environment.locationCondition[Environment.roverAgentLocation] == 0
                print(Environment.roverAgentLocation, " has no rocks")
            break
            
        print('''                                                                        
        
        ''')
            
        newIndex = Environment.Location.index(Environment.roverAgentLocation) + 1
        
        print("---- Exploration Venture 1 -----")
        print(Environment.locationCondition)
        print("Rover is in location ", Environment.roverAgentLocation)
        
        count = 0
        while count < 8:
            if Environment.locationCondition[Environment.roverAgentLocation] == 1:
                Environment.locationCondition[Environment.roverAgentLocation] = 0
                print(Environment.roverAgentLocation, " has been sampled before")
            else:
                Environment.locationCondition[Environment.roverAgentLocation] == 0
                print(Environment.roverAgentLocation, " has no rocks")
            break
            
        newIndex = Environment.Location.index(Environment.roverAgentLocation) + 1
        count += 1
        print("Location sampled ", Environment.locationCondition)
        print("Rovers perfomance 75%")
        
        
        
        
        
        
        
        
E1 = Environment()
A1 = roverAgent(E1)
# Out:
# ---- Exploration Venture 0 -----
# {'A': 1, 'B': 0, 'C': 1, 'D': 0, 'E': 0, 'F': 1, 'G': 1, 'H': 1}
# Rover is in location  H
# H  has been sampled
#
#
#
# ---- Exploration Venture 1 -----
# {'A': 1, 'B': 0, 'C': 1, 'D': 0, 'E': 0, 'F': 1, 'G': 1, 'H': 0}
# Rover is in location  H
# H  has no rocks
# Location sampled  {'A': 1, 'B': 0, 'C': 1, 'D': 0, 'E': 0, 'F': 1, 'G': 1, 'H': 0}
# Rovers perfomance 75%
